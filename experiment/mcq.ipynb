# %%
import os
import json
import pandas as pd
import traceback

# %%
from langchain_openai import ChatOpenAI

# %%
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
KEY=os.getenv("OPENAI_API_KEY")

# %%
print(KEY)
# Out:
# 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
